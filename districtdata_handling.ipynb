# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('india_20jul_2019_drms_dis.csv', delim_whitespace=True, names=["Id", "name", "year", "obs", "jan", "feb", "mar", "apr", "may", "jun", "jul", "aug", "sep", "oct", "nov", "dec", "total", "JF", "MAM", "JJAS", "OND"],index_col=3)
# Out:
# C:\Users\chandrima pc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,15,16,17,18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#df

# %%
df= df.drop('PERD', axis=0)

# %%
df
# Out:
#           Id       name  year     jan     feb    mar    apr    may    jun  \
# obs
# ACTL  300101  ANANTAPUR  1901     3.6    39.4    0.0   10.1   70.1   38.7
# ACTL  300101  ANANTAPUR  1902     5.0     0.0    0.1   28.4   41.7   74.6
# ACTL  300101  ANANTAPUR  1903     0.8     0.0    0.0   11.1   50.0   68.9
# ACTL  300101  ANANTAPUR  1904     1.9     0.0    0.0   16.2   97.9   32.1
# ACTL  300101  ANANTAPUR  1905     2.2     2.5   12.8    9.0   57.4   43.9
# ...      ...        ...   ...     ...     ...    ...    ...    ...    ...
# ACTL  293433     MULUGU  2016  -999.9  -999.9 -999.9 -999.9 -999.9 -999.9
# ACTL  293433     MULUGU  2017  -999.9  -999.9 -999.9 -999.9 -999.9 -999.9
# ACTL  293433     MULUGU  2018  -999.9  -999.9 -999.9 -999.9 -999.9 -999.9
# ACTL  293433     MULUGU  2019  -999.9  -999.9 -999.9 -999.9 -999.9 -999.9
# STNS  293433     MULUGU  2018       4       0    4.0    4.0    3.0    4.0
#
# ...

# %%
df=df.reset_index(drop = True)

# %%
df
# Out:
#            Id       name  year     jan     feb    mar    apr    may    jun  \
# 0      300101  ANANTAPUR  1901     3.6    39.4    0.0   10.1   70.1   38.7
# 1      300101  ANANTAPUR  1902     5.0     0.0    0.1   28.4   41.7   74.6
# 2      300101  ANANTAPUR  1903     0.8     0.0    0.0   11.1   50.0   68.9
# 3      300101  ANANTAPUR  1904     1.9     0.0    0.0   16.2   97.9   32.1
# 4      300101  ANANTAPUR  1905     2.2     2.5   12.8    9.0   57.4   43.9
# ...       ...        ...   ...     ...     ...    ...    ...    ...    ...
# 79350  293433     MULUGU  2016  -999.9  -999.9 -999.9 -999.9 -999.9 -999.9
# 79351  293433     MULUGU  2017  -999.9  -999.9 -999.9 -999.9 -999.9 -999.9
# 79352  293433     MULUGU  2018  -999.9  -999.9 -999.9 -999.9 -999.9 -999.9
# 79353  293433     MULUGU  2019  -999.9  -999.9 -999.9 -999.9 -999.9 -999.9
# 79354  293433     MULUGU  2018       4       0    4.0    4.0    3.0    4.0
#
# ...

# %%
intex = df.Id.drop_duplicates().values

# %%
intex
# Out:
# array([300101, 300102, 300103, 280104, 280105, 280106, 300107, 280108,
#        280109, 280110, 280111, 280112, 280113,  20201,  20202,  20203,
#         20204,  20205,  20206,  20207,  20208,  20209,  20210,  20211,
#         20212,  20213,  20214,  20215,  20216,  30301,  30302,  30303,
#         30304,  30305,  30306,  30307,  30308,  30309,  30310,  30311,
#         30312,  30313,  30314,  30315,  30316,  30317,  30318,  30319,
#         30320,  30321,  30322,  30323,  30324,  30325,  30326,  30327,
#         90401,  90402,  90403,  90404,  90405,  90406,  90407,  90408,
#         90409,  90410,  90411,  90412,  90413,  90414,  90415,  90416,
#         90417,  90418,  90419,  90420,  90421,  90422,  90423,  90424,
#         90425,  90426,  90427,  90428,  90429,  90430,  90431,  90432,
#         90433,  90434,  90435,  90436,  90437,  90438, 210501, 220502,
#        210503, 210504, 220505, 210506, 210507, 210508, 220509, 220510,
# ...

# %%
df_n=df[['Id','name']].drop_duplicates()

# %%
df_n
# Out:
#            Id           name
# 0      300101      ANANTAPUR
# 119    300102        CHITTOR
# 239    300103       CUDDAPAH
# 359    280104           EAST
# 598    280105         GUNTUR
# ...       ...            ...
# 78866  293430       WARANGAL
# 79104  293431        YADADRI
# 79105  293431  Y.BHUVANAGIRI
# 79194  293432     NARAYANPET
# 79264  293433         MULUGU
#
# [798 rows x 2 columns]

# %%
for i in range(len(intex)):
    name = df_n[df_n['Id']==intex[i]]
    aa   = df[df['Id']==intex[i]]

    name = name['name'].iloc[0].split('(')[0]
    name = name.split('(')[0]
    name = name.split('/')[0]
    name = name.replace(" ", "")
    name = name.replace("%", "")
    name = name.replace("<", "")


    aa.to_csv('district_files/'+name+'.csv')

# %%
#dff=pd.read_csv('district_files/BADWANI.csv')

# %%
#dff
